# %%
'''
Chef wants to give a burger party to all his 
N
N friends i.e. he wants to buy one burger for each of his friends.
The cost of each burger is 
X
X rupees while Chef has a total of 
K
K rupees.

Determine whether he has enough money to buy a burger for each of his friends or not

Explanation:
Test case 
1
1: Chef has 
5
5 friends. The cost of buying a burger for each of them will be 
10
×
5
=
50
10×5=50 while Chef has 
70
70 rupees. Therefore, he can buy a burger for all of them.

Test case 
2
2: Chef has 
5
5 friends. The cost of buying a burger for each of them will be 
10
×
5
=
50
10×5=50 while Chef has 
40
40 rupees. Therefore, he can not buy a burger for all of them.

Test case 
3
3: Chef has 
10
10 friends. The cost of buying a burger for each of them will be 
40
×
10
=
400
40×10=400 and Chef has 
400
400 rupees. Therefore, he can buy a burger for all of them.

Test case 
4
4: Chef has 
14
14 friends. The cost of buying a burger for each of them will be 
14
×
14
=
196
14×14=196 while Chef has 
150
150 rupees. Therefore, he can not buy a burger for all of them
'''

# %%
def burgers(N, X, K):
    total_cost = N * X
    return total_cost <= K

# Test cases
test_cases = [
    # can buy burgers
    (5, 10, 70),   
    # can't buy burgers
    (5, 10, 40),   
    # can buy burgers
    (10, 40, 400), 
    # can't buy burgers
    (14, 14, 150)  
]

for N, X, K in test_cases:
    result = burgers(N, X, K)
    print(f"The Case: {N} N friends, {X} X rupees per burger, {K} K rupees available")
    if result:
        print("Can buy a burger for each friend")
    else:
        print("Can't buy a burger for each friend")
    print()
# Out:
# The Case: 5 N friends, 10 X rupees per burger, 70 K rupees available
# Can buy a burger for each friend
#
# The Case: 5 N friends, 10 X rupees per burger, 40 K rupees available
# Can't buy a burger for each friend
#
# The Case: 10 N friends, 40 X rupees per burger, 400 K rupees available
# Can buy a burger for each friend
#
# The Case: 14 N friends, 14 X rupees per burger, 150 K rupees available
# Can't buy a burger for each friend
